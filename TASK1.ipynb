# %%
import numpy as pd
import pandas as pa

# %%
df =pd.read_csv(r"")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df =pd.read_csv(r"")
#
# File c:\Users\akhil\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\__init__.py:347, in __getattr__(attr)
#     344     "Removed in NumPy 1.25.0"
#     345     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 347 raise AttributeError("module {!r} has no attribute "
#     348                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'read_csv'
